# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
from PIL import Image

# %%
import cv2
import matplotlib.pyplot as plt

def cv2_imshow(image):
    return plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))

def plt_format(image):
    return cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# %%
import cv2
cv2.useOptimized()
# Out:
# True

# %%
# 函数图像绘制
#y=x*x

#x轴

x = numpy.linspace(-10,10,200)
# print(x)
#y轴
y = [i**2 for i in x]

#绘制
plt.grid(linestyle=':')

plt.plot(x,y)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
def get_normal(n):
    mu,sigma = 10,1
    s = np.random.normal(mu, sigma, n)
    print(s)
    plt.hist(s, density=True)
    plt.show()
get_normal(100)
# Out:
# [10.31848884  9.03369302  9.58295963 10.36425324 12.0550189  11.58699704
#   8.40081178  9.82603844  9.06240319 10.72112359 10.01475079  9.92374933
#  10.04560867  9.24042694 11.24457088 11.03045961 11.21213162  8.96604389
#   7.90228809 11.53725658 11.06736971  8.38771279  9.82730157 11.25420518
#  10.13024893 10.16972961 10.33101744 10.13055922  9.81776965 11.66148548
#  10.3242931   9.13248835 11.19121706 10.88115533  9.8519029   9.35883566
#   9.27431152  8.87775539 11.20721254  8.72138686 10.59465339 10.21992562
#   9.34230356 11.50884164 11.41574964 10.41880636  8.02674417  9.99089033
#  10.1698316   9.29680519 11.08404191  8.31642909 10.59307805  8.37457376
#  10.63597017 10.15417572  8.08165483 10.30944601  9.60020034  9.10720879
#   9.28104945  8.8872296  11.32253599 10.3145708  10.54114714 10.55599438
#  12.04586416  8.87943207  9.47843883 10.07726723 10.70016942 10.34553985
#   9.58414188 11.44249608 11.05864508 12.0114206  10.3545312   9.88302793
# ...

# %%
# 决策树可视化
from sklearn.datasets import load_iris
from sklearn.tree import DecisionTreeClassifier,export_graphviz
dot_data=export_graphviz(clf,feature_names=iris_feat_names,out_file=None)
dot=graphviz.Source(dot_data)
dot.view()

# %%
from graphviz import Digraph

graph = Digraph(
    engine="circo",
    comment="测试",
    format="png"
)

nodeTexts = ["xx","鬼谷子"]
nodeFontName = "SimSun"

graph.node(nodeTexts[0], fontname=nodeFontName)
graph.node(nodeTexts[1], fontname=nodeFontName)
graph.edge(nodeTexts[0], nodeTexts[1], "就是", fontname=nodeFontName)
graph.view()
# Out:
# 'Digraph.gv.png'

# %%
fig, ax = plt.subplots()
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
plt.xlim(0,7) #x坐标轴范围-10~10
plt.ylim(0,7)
plt.plot([4,2],[3,6])
plt.savefig('math/kx+b.svg', dpi=600, format='svg')
plt.show()
# plt.savefig('math/kx+b.jpg')

# %%
x=np.linspace(-1,3)
y=-2*x+4
plt.xlim(-5,5)
plt.ylim(-5,5)

ax=plt.gca()  #gca:get current axis得到当前轴
#设置图片的右边框和上边框为不显示
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
#挪动x，y轴的位置，也就是图片下边框和左边框的位置
ax.spines['bottom'].set_position(('data',0))  #data表示通过值来设置x轴的位置，将x轴绑定在y=0的位置
ax.spines['left'].set_position(('data',0))  #axes表示以百分比的形式设置轴的位置，即将y轴绑定在x轴50%的位置，也就是x轴的中点
ax.axes.xaxis.set_visible(False)
ax.axes.yaxis.set_visible(False)
x2 = np.array([1, 1.5])
y2 = np.array([2, 1])
# 画点

plt.scatter(x2,y2, 50, color ='blue')
plt.text(x2, y2, '1', ha='center', va='bottom', fontsize=8)
# 公式及箭头
# plt.annotate(r'$\cos(\frac{2\pi}{3})=-\frac{1}{2}$',)
             # xy=(t, np.cos(t)),  xycoords='data',
             # xytext=(-90, -50), textcoords='offset points', fontsize=16,
             # arrowprops=dict(arrowstyle="->", connectionstyle="arc3,rad=.2"))
# plt.scatter(x2, y2)

plt.plot(x,y)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# D:\Miniconda3\lib\site-packages\IPython\core\formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# D:\Miniconda3\lib\site-packages\IPython\core\pylabtools.py in print_figure(fig, fmt, bbox_inches, base64, **kwargs)
#     149         FigureCanvasBase(fig)
#     150
# --> 151     fig.canvas.print_figure(bytes_io, **kw)
#     152     data = bytes_io.getvalue()
#     153     if fmt == 'svg':
#
# D:\Miniconda3\lib\site-packages\matplotlib\backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
# ...

# %%
# 尺寸和dpi
plt.figure(figsize=(8,5), dpi=80)
ax = plt.subplot(111)
# 不显示上边框和右边框
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.xaxis.set_ticks_position('bottom')
ax.spines['bottom'].set_position(('data',0))
# 更换标签显示方向
ax.yaxis.set_ticks_position('left')
ax.spines['left'].set_position(('data',0))
# x轴y轴
x=np.linspace(-2,2)
y=2*x+1
plt.xlim(-5,5)
plt.ylim(-5,5)

plt.plot(x, y, color="blue", linewidth=2.5, linestyle="-", label="")
# plt.plot(X, S, color="red", linewidth=2.5, linestyle="-",  label="sine")

# 最大显示1.1倍，增加tick
# plt.xlim(X.min()*1.1, X.max()*1.1)
# plt.xticks([-np.pi, -np.pi/2, 0, np.pi/2, np.pi],
#            [r'$-\pi$', r'$-\pi/2$', r'$0$', r'$+\pi/2$', r'$+\pi$'])

# plt.ylim(C.min()*1.1,C.max()*1.1)
# plt.yticks([-1, +1],
#            [r'$-1$', r'$+1$'])
ax.axes.xaxis.set_visible(False)
ax.axes.yaxis.set_visible(False)
# 画虚线
t = 2*np.pi/3
plt.plot([t,t],[0,np.cos(t)],
         color ='blue',  linewidth=1.5, linestyle="--")
# 画点
plt.scatter([t,],[np.cos(t),], 50, color ='blue')
# 公式及箭头
plt.annotate(r'$\cos(\frac{2\pi}{3})=-\frac{1}{2}$',
             xy=(t, np.cos(t)),  xycoords='data',
             xytext=(-90, -50), textcoords='offset points', fontsize=16,
             arrowprops=dict(arrowstyle="->", connectionstyle="arc3,rad=.2"))

plt.plot([t,t],[0,np.sin(t)],
         color ='red',  linewidth=1.5, linestyle="--")
plt.scatter([t,],[np.sin(t),], 50, color ='red')
plt.annotate(r'$\sin(\frac{2\pi}{3})=\frac{\sqrt{3}}{2}$',
             xy=(t, np.sin(t)),  xycoords='data',
             xytext=(+10, +30), textcoords='offset points', fontsize=16,
             arrowprops=dict(arrowstyle="->", connectionstyle="arc3,rad=.2"))
# 颜色标志
plt.legend(loc='upper left', frameon=False)
# plt.savefig("math/exercice_9.png",dpi=72)
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
# 尺寸和dpi
plt.figure(figsize=(8,5), dpi=80)
ax = plt.subplot(111)
# 不显示上边框和右边框
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.xaxis.set_ticks_position('bottom')
ax.spines['bottom'].set_position(('data',0))
# 更换标签显示方向
ax.yaxis.set_ticks_position('left')
ax.spines['left'].set_position(('data',0))
# x轴y轴
X = np.linspace(-np.pi, np.pi, 256,endpoint=True)
C,S = np.cos(X), np.sin(X)

plt.plot(X, C, color="blue", linewidth=2.5, linestyle="-", label="cosine")
plt.plot(X, S, color="red", linewidth=2.5, linestyle="-",  label="sine")

# 最大显示1.1倍，增加tick
plt.xlim(X.min()*1.1, X.max()*1.1)
plt.xticks([-np.pi, -np.pi/2, 0, np.pi/2, np.pi],
           [r'$-\pi$', r'$-\pi/2$', r'$0$', r'$+\pi/2$', r'$+\pi$'])

plt.ylim(C.min()*1.1,C.max()*1.1)
plt.yticks([-1, +1],
           [r'$-1$', r'$+1$'])
ax.axes.xaxis.set_visible(False)
ax.axes.yaxis.set_visible(False)
# 画虚线
t = 2*np.pi/3
plt.plot([t,t],[0,np.cos(t)],
         color ='blue',  linewidth=1.5, linestyle="--")
# 画点
plt.scatter([t,],[np.cos(t),], 50, color ='blue')
# 公式及箭头
plt.annotate(r'$\cos(\frac{2\pi}{3})=-\frac{1}{2}$',
             xy=(t, np.cos(t)),  xycoords='data',
             xytext=(-90, -50), textcoords='offset points', fontsize=16,
             arrowprops=dict(arrowstyle="->", connectionstyle="arc3,rad=.2"))

plt.plot([t,t],[0,np.sin(t)],
         color ='red',  linewidth=1.5, linestyle="--")
plt.scatter([t,],[np.sin(t),], 50, color ='red')
plt.annotate(r'$\sin(\frac{2\pi}{3})=\frac{\sqrt{3}}{2}$',
             xy=(t, np.sin(t)),  xycoords='data',
             xytext=(+10, +30), textcoords='offset points', fontsize=16,
             arrowprops=dict(arrowstyle="->", connectionstyle="arc3,rad=.2"))
# 颜色标志
plt.legend(loc='upper left', frameon=False)
# plt.savefig("math/exercice_9.png",dpi=72)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

#x轴
x = np.arange(-2*(np.pi),2*(np.pi),0.001)

#y轴 
y = np.cos(x)+np.sin(x)
z = 2*np.cos(x)+3*np.sin(x)
# 网格线
plt.grid(linestyle=':')
plt.plot(x,y,label="X*cos+Y*sin")
plt.plot(x,z,label="Z")

plt.xlabel("x")
plt.ylabel("y")
# plt.title("cos")
# 显示线的标识
plt.legend()
plt.show()
